# %% [markdown]
# #### Zero-shot Topic Classification

# %% [markdown]
# The most modern and reliable Topic Classification approach in terms of accuracy is to use a pre-trained **zero-shot** classifier model. This is greatly adaptable to our task where we have a considerable amount of labels but not the training data to back it up or the computational resources to fully train a model.
#
# Note: For performance reasons, using a GPU is highly recommended when dealing with these types of models hence the notebook starts with a GPU check on the system.

# %%
import torch

print('Cuda Device Found? ', torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available() == True:
    print('Type of Cuda Device:', torch.cuda.get_device_name(device))
# Out:
# Cuda Device Found?  True
# Type of Cuda Device: NVIDIA GeForce GTX 1650 Ti

# %%
import pandas as pd
from transformers import pipeline

df = pd.read_excel('data/textcat_fewshot_data.xlsx')
data = {}

for column in df.columns:
    data[column] = df[column].dropna().tolist()

print('Training Custom Dataset Loaded')
all_labels = [label for label in data.keys()]
# Out:
# c:\Users\Genis\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Training Custom Dataset Loaded

# %% [markdown]
# Pre-trained **zero-shot** Classifier using PyTorch as a framework.
#
# Device = **-1** for CPU | Device = **0** for GPU
#
# Note: CPU runtime is 7x slower.

# %%
zero_shot_classifier = pipeline("zero-shot-classification", model = "facebook/bart-large-mnli", device = 0, framework = "pt")

# %% [markdown]
# Compute scores for a batch of example sentences using Zero Shot Classification on the chosen pre-trained model.

# %%
example_sentences = ["who developed these medical and bio sensors?", "AI will surely be the future of Digital Health.", 
                     "She works as PR to outreach communities in LinkedIn and organize workshops.", "Developing Image Segmentation systems is one my favourite hobbies.", 
                     "This digital application will accelerate communication in LMICs.", "Immigrant communities are often faced with racism.", 
                     "I might start a PhD related to EHRs in health systems.", "We performed statistical analysis between variables during this research.",
                     "Waste incineration is often overlooked as a cause of air pollution.", "Every human should have a right to universal healthcare access.", 
                     "Smoking and alcohol consumption often lead to obesity.", 
                     "Virtual doctor consultations are essential for remote areas where there is a lack of health professionals."]

all_scores = zero_shot_classifier(
    sequences = example_sentences,
    candidate_labels = all_labels,
    multi_label = True,
    src_lang="en",
)

# %% [markdown]
# ##### Output Scores (Multi-Label)
#
# After multi-label predictions are made for each sentence, a scoring function gathering the total counts is computed. This function is designed for our task to classify a full document made up of hundreds of sentences.

# %%
def process_scores(pipeline_scores, topic_labels):
    topics_count = {label: 0 for label in topic_labels}

    for score in pipeline_scores:
        print("For Sentence: {}".format(score['sequence']))
        high_probas = [proba for proba in score['scores'] if proba >= 0.6]
        assigned_labels = []
        for i in range(len(high_probas)):
            assigned_labels.append(score['labels'][i])
            topics_count[score['labels'][i]] += 1
        print("Assigned Labels: {}".format(assigned_labels))
        print()
    
    sorted_count = sorted(topics_count.items(), key = lambda x: x[1], reverse = True)
    print('Final Count: {}'.format(sorted_count))
    
    
process_scores(all_scores, all_labels)
# Out:
# For Sentence: who developed these medical and bio sensors?
# Assigned Labels: []
#
# For Sentence: AI will surely be the future of Digital Health.
# Assigned Labels: ['Artificial Intelligence', 'Digital Health']
#
# For Sentence: She works as PR to outreach communities in LinkedIn and organize workshops.
# Assigned Labels: ['Community Outreach', 'Lifestyle Factors']
#
# For Sentence: Developing Image Segmentation systems is one my favourite hobbies.
# Assigned Labels: []
#
# For Sentence: This digital application will accelerate communication in LMICs.
# Assigned Labels: []
#
# For Sentence: Immigrant communities are often faced with racism.
# Assigned Labels: ['Discrimination']
#
# For Sentence: I might start a PhD related to EHRs in health systems.
# Assigned Labels: ['Electronic Health Records', 'eHealth']
#
# For Sentence: We performed statistical analysis between variables during this research.
# Assigned Labels: ['Data Analysis', 'Systematic Review']
#
# For Sentence: Waste incineration is often overlooked as a cause of air pollution.
# Assigned Labels: []
#
# For Sentence: Every human should have a right to universal healthcare access.
# Assigned Labels: ['Human Rights', 'Global Health', 'Humanitarian Response', 'Public Health Law']
#
# For Sentence: Smoking and alcohol consumption often lead to obesity.
# Assigned Labels: ['Lifestyle Factors', 'Empirical Study', 'Global Health']
#
# For Sentence: Virtual doctor consultations are essential for remote areas where there is a lack of health professionals.
# Assigned Labels: ['Telemedicine', 'Digital Health', 'Humanitarian Response']
#
# Final Count: [('Digital Health', 2), ('Global Health', 2), ('Humanitarian Response', 2), ('Lifestyle Factors', 2), ('Artificial Intelligence', 1), ('Community Outreach', 1), ('Data Analysis', 1), ('Discrimination', 1), ('eHealth', 1), ('Electronic Health Records', 1), ('Empirical Study', 1), ('Human Rights', 1), ('Public Health Law', 1), ('Systematic Review', 1), ('Telemedicine', 1), ('Biomedical Engineering', 0), ('Clinical Decision Support', 0), ('Computer Vision', 0), ('Decision Making', 0), ('Diagnostic Assessments', 0), ('Digital Accelerators', 0), ('Environmental Conservation', 0), ('Evidence From Patients', 0), ('Global Threats', 0), ('Healthcare Financing', 0), ('Knowledge Management', 0), ('Literature Review', 0), ('Logistics and Supply Chain', 0), ('Medical Imaging', 0), ('Medical Report', 0), ('Natural Language Processing', 0), ('Others', 0), ('Propositions and Guidelines', 0), ('Publicly Funded Science', 0), ('Regional Implementation', 0), ('Risk Management', 0), ('Social Analysis', 0), ('Substance Abuse', 0), ('Surgery', 0), ('Sustainable Development Goals', 0), ('Violence', 0)]

# %% [markdown]
# ##### Document Processing

# %%
import re
from nltk.tokenize import sent_tokenize
from process_single_document import extract_text_from_pdf, remove_references, try_finding_keywords

##### Document extraction and pre-processing (Removing Referencesn & Potentially finding Keywords) 
single_pdf = open('data/implementome_publications/test_miner/child_obesity_switzerland.pdf', 'rb')
doc_as_str, doc_as_list = extract_text_from_pdf(single_pdf)
doc_as_str = remove_references(doc_as_str)
doc_keywords = try_finding_keywords(doc_as_str)

###### Tokenization process of the string containing the entire document text
###### Regular Expression pattern removes '\n' characters and tries to concatenate words separated by a '-'
sentences = sent_tokenize(doc_as_str)
pattern = r'(?<![a-zA-Z])-|-(?![a-zA-Z])'
sentences = [re.sub(pattern, '', sentence.replace('\n', ' ')) for sentence in sentences]

# sorted_categories = sorted(predicted_categories.items(), key = lambda x: x[1], reverse=True)

fixed_sentences = [sentence for sentence in sentences if len(sentence) >= 50]
# Out:
# Text from PDF File (11 pages) extracted successfully.
# Original document character length: 44197
# References removed, new document character length: 36152

# %%
import time

start = time.time()
doc_scores = zero_shot_classifier(
    sequences = fixed_sentences,
    candidate_labels = all_labels,
    multi_label = True,
    src_lang="en",
)
end = time.time() - start

# %%
print("Topic Classification | Document Processing Finished | Elapsed Time: {:.4f}s | Time per Sentence: {:.4f}s".format(end, end / len(fixed_sentences)))
# Out:
# Topic Classification | Document Processing Finished | Elapsed Time: 410.3804s | Time per Sentence: 1.9730s

# %%
process_scores(doc_scores, all_labels)
# Out:
# For Sentence: BMC Public Health          (2021) 21:243  https://doi.org/10.1186/s12889021102130 R E S E A R C H A R T I C L E Open Access The increase in child obesity in Switzerland is mainly due to migration from Southern Europe – a cross-sectional study Urs Eiholzer*, Chris Fritz and Anika Stephan Abstract Background: Novel height, weight and body mass index (BMI) references for children in Switzerland reveal an increase in BMI compared to former percentile curves.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: This trend may be the result of children with parents originating from Southern European countries having a higher risk of being overweight compared to their peers with parents of Swiss origin.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: We examined the association of generational, migration-related and socioeconomic factors on BMI in Switzerland and expect the results to lead to more targeted prevention programs.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Methods: From contemporary cross-sectional data, we calculated subgroup-specific BMI percentiles for origin.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Results for children of Swiss origin were compared with historical BMI data from Zurich.
# Assigned Labels: ['Data Analysis', 'Global Health', 'Regional Implementation']
#
# For Sentence: We tested for the association of overweight and obesity with origin and compared the distributions of BMI percentile ranks.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Logistic regression analyses were applied to predict probabilities of being overweight or obese by origin and the Swiss neighborhood index of socioeconomic position (SSEP).
# Assigned Labels: []
#
# For Sentence: Results: Compared to the BMI from two generations ago, the newly calculated BMI increased only slightly for children with both parents from Switzerland; 1.2% of these girls and 1.6% of these boys are obese.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: In the Swiss population, 13% of the children have parents from Southern Europe and the proportion of obesity is 57 and 42% in these boys and girls, respectively.
# Assigned Labels: []
#
# For Sentence: Their BMI medians correspond to those of their parents’ countries of origin.
# Assigned Labels: []
#
# For Sentence: For the probability of being overweight or obese, the SSEP differences are less important than the status of origin.
# Assigned Labels: []
#
# For Sentence: Conclusion: We identified children with both parents from Southern Europe as the main influence driving the increase in BMI in Switzerland over the past 50 years.
# Assigned Labels: ['Data Analysis', 'Social Analysis', 'Empirical Study', 'Global Health']
#
# For Sentence: A differentiated consideration of the proportions of various migrant groups within cross-sectional samples is essential when monitoring BMI.
# Assigned Labels: []
#
# For Sentence: Ignoring fluctuations can lead to false conclusions.
# Assigned Labels: []
#
# For Sentence: Keywords: Overweight, Obesity, Migration, Children, BMI Background In Europe, the prevalence of obesity in children and ado lescents has been rising since the 1980s [1].
# Assigned Labels: []
#
# For Sentence: While the proportions of overweight and obese children have more or less stabilized or decreased in Northern and Central Europe between 1999 and 2016, these numbers are still * Correspondence: urs.eiholzer@pezz.ch Center for Paediatric Endocrinology Zurich (PEZZ), Moehrlistrasse 69, CH8006 Zurich, Switzerland increasing for children from Southern Europe that have the highest prevalence rates [1].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Recent data collected from school-aged children in Switzerland between 2002 and 2017 shows a weak but significantly declining trend in overweight and obesity [2].
# Assigned Labels: ['Data Analysis', 'Global Health']
#
# For Sentence: Demographic changes through migration are likely to influence the prevalence of obesity.
# Assigned Labels: ['Global Health']
#
# For Sentence: As 25% of the people residing in Switzerland today are migrants, a differenti to ated view regarding national origin is essential © The Author(s).
# Assigned Labels: []
#
# For Sentence: 2021 Open Access This article is licensed under a Creative Commons Attribution 4.0 International License, which permits use, sharing, adaptation, distribution and reproduction in any medium or format, as long as you give appropriate credit to the original author(s) and the source, provide a link to the Creative Commons licence, and indicate if changes were made.
# Assigned Labels: ['Clinical Decision Support']
#
# For Sentence: The images or other third party material in this article are included in the article's Creative Commons licence, unless indicated otherwise in a credit line to the material.
# Assigned Labels: ['Others']
#
# For Sentence: If material is not included in the article's Creative Commons licence and your intended use is not permitted by statutory regulation or exceeds the permitted use, you will need to obtain permission directly from the copyright holder.
# Assigned Labels: []
#
# For Sentence: To view a copy of this licence, visit http://creativecommons.org/licenses/by/4.0/.
# Assigned Labels: []
#
# For Sentence: The Creative Commons Public Domain Dedication waiver (http://creativecommons.org/publicdomain/zero/1.0/) applies to the data made available in this article, unless otherwise stated in a credit line to the data.
# Assigned Labels: []
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 2 of 11 understand the variations in the prevalence of over weight and obesity.
# Assigned Labels: []
#
# For Sentence: The immigrant population profile in Switzerland has diversified from mainly unqualified Spanish and Italian workers in the 1960s and immigrants from Portugal and the former Yugoslavia in the 1990s towards a large proportion of tertiary educated European Union citizens within the last twenty years.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: Currently, the largest foreign populations in Switzerland are from Italy followed by Germany, Portugal, and France.
# Assigned Labels: ['Social Analysis', 'Data Analysis']
#
# For Sentence: references were published for In 2019, new height, weight and body mass index (BMI) children in Switzerland, including those with parents of non-Swiss origin [3].
# Assigned Labels: ['Data Analysis', 'Propositions and Guidelines']
#
# For Sentence: The comparison of today’s children with the former percentile curves of Prader et al.
# Assigned Labels: []
#
# For Sentence: two generations ago [4] showed an increase in BMI.
# Assigned Labels: []
#
# For Sentence: Further, it was shown that children with parents originating from Southern Europe have a 2.5fold higher risk of being overweight over children with both parents of Swiss ori gin [3].
# Assigned Labels: ['Data Analysis', 'Risk Management']
#
# For Sentence: Switzerland is a small country with an obligatory resi dence register and an up-to-date migration statistics database, which applies for all 26 cantons.
# Assigned Labels: ['Regional Implementation', 'Risk Management']
#
# For Sentence: Therefore, it is possible to study the influence of migration on weight in greater detail.
# Assigned Labels: []
#
# For Sentence: In this paper, we examine the gener ational, migration-related and socioeconomic factors as sociated with the prevalence of overweight and obesity of children in Switzerland.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: Methods For this study, we used cross-sectional data collected from boys and girls aged between 0 to 20 years living in Switzerland; the methods used for data collection and data cleaning processes have already been described in detail [3].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Briefly, our sample comprised prospectively measured data of 12,543 children and adolescents col lected at pediatric practices and schools, which we refer to as our “contemporary core sample” throughout the remainder of this article.
# Assigned Labels: []
#
# For Sentence: These data were originally sup plemented with three external retrospective data sets that were excluded for the purposes of this study be cause detailed information outlining the origin of par ents was not documented [3].
# Assigned Labels: ['Data Analysis', 'Empirical Study']
#
# For Sentence: From our contemporary core sample, the following variables of BMI, age, sex, Swiss neighborhood index of socioeconomic position (SSEP), origin of the mother and origin of the father were used for analysis.
# Assigned Labels: ['Data Analysis', 'Lifestyle Factors', 'Social Analysis']
#
# For Sentence: Origin of the mother/father indicates the region of birth.
# Assigned Labels: []
#
# For Sentence: Countries, if not themselves coded as a region, were not documented.
# Assigned Labels: []
#
# For Sentence: Regions were defined as: (1) Switzerland, (2) Northern/ Central Europe: Germany, Austria, France, Belgium, Netherlands, Luxembourg, Sweden, Finland, Norway, Denmark, (3) Italy, Portugal, Spain, (4) Balkan region: Albania, Bosnia-Herzegovina, Bulgaria, Greece, Kosovo, Croatia, Moldova, Montenegro, Northern Macedonia, (2) Northern/Central Europe (3) Romania, Serbia, Slovenia, (5) Turkey, (6) other coun tries.
# Assigned Labels: ['Regional Implementation']
#
# For Sentence: Based on the combination of each parent’s origin (1) we defined the following categories for origin: Italy, Switzerland, Portugal, Spain, (4) Balkan region (5) Turkey, (6) one parent from Switzerland, or (7) other: parents not from the same region/one or both from other regions.
# Assigned Labels: ['Others', 'Data Analysis', 'Social Analysis']
#
# For Sentence: In this publication, we applied the term “Southern Europe” to encompass all three defined origin categories of Italy, Portugal, Spain as well as the Balkan region and Turkey.
# Assigned Labels: ['Regional Implementation']
#
# For Sentence: The SSEP is an area-based index expressed as median per postal code area and combines information on in come, education and occupation, whereby data are based on the structural survey of 2012–2015 [5].
# Assigned Labels: []
#
# For Sentence: Sex-specific BMI percentile curves by origin were cal culated with the LMS method [6].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: For the evaluation of model fit, we used Q tests [7].
# Assigned Labels: []
#
# For Sentence: All notation for percentiles employed the term “P” and the number indicating the nth percentile; for ex ample, the 50th percentile was labelled “P50”.
# Assigned Labels: []
#
# For Sentence: We compared P10, P50 and P90 for children with both parents of Swiss origin to children two generations ago (also known as the “Prader sample” for the purposes of this work) from the respective smoothed BMI-for-age percentiles of the working group of Prader [4].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Differ ences were calculated in kilograms per meters squared (kg/m2) and in kilograms (kg) for a boy or girl of P50 height-for-age.
# Assigned Labels: []
#
# For Sentence: Prevalence of overweight including obesity and of obesity alone, were calculated using the International Obesity Task Force (IOTF) cut-offs.
# Assigned Labels: []
#
# For Sentence: These cutoffs are defined by the percentiles at BMI values of 25 kg/m2 and 30 kg/m2 at the age of 18 years throughout childhood and adolescence and were derived from six large data sets the from Brazil, Great Britain, Hong Kong, Netherlands, Singapore, and the United States [8].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: We applied a χ2test for association between IOTF category (non-overweight, overweight, obese) and origin.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Add itionally, we calculated the distributions of origin within the total sample and within individuals categorized as overweight (including obese) and obese.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: For analyzing the association with origin, we calculated the sex-specific empirical cumulative distribution func tions of percentile ranks based on the new Swiss BMI percentiles [3] and plotted the deviations by origin.
# Assigned Labels: ['Data Analysis', 'Empirical Study']
#
# For Sentence: This was made with the intention to also evaluate differences in the lower and middle ranges of BMI without focusing only on the prevalence of overweight and obesity.
# Assigned Labels: []
#
# For Sentence: To in clude the Prader sample in this plot, we calculated z values for the new Swiss BMI P3, P10, P25, P50, P75, P90 and P97 with respect to the age and sex-specific Prader means and standard deviations, and transformed z into percentile ranks.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 3 of 11 To visualize the fit of the BMI percentiles for the groups of children with parents of non-Swiss origin, we plotted their raw data and group-specific P10, P50 and P90 over the new P10, P50 and P90 for Switzerland [3], and added available percentiles of the respective Euro pean countries or regions (i.e.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Italy [9], Spain [10], Portugal [11], Albania [12], Macedonia [13], Serbia [14], Turkey [15–19], Germany [20], and Austria [21]).
# Assigned Labels: ['Others', 'Global Threats', 'Community Outreach', 'Regional Implementation', 'Decision Making', 'Clinical Decision Support']
#
# For Sentence: We predicted probabilities of being overweight or obese by applying logistic regression for children dependent on their parents’ origin and SSEP [3].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Origin was dichotomized (‘both parents from Switzerland’ ver sus ‘both parents from Southern Europe’) and the sam ple included only children of ≥8 years.
# Assigned Labels: []
#
# For Sentence: For LMS modelling, we used LMSchartmaker Pro ver sion 2.54 (Medical Research Council, Cambridge, UK).
# Assigned Labels: ['Publicly Funded Science']
#
# For Sentence: For logistic regression analyses, we used Stata version 14.0 (StataCorp, Texas, USA).
# Assigned Labels: ['Data Analysis']
#
# For Sentence: All other analyses were performed with IBM SPSS Statistics for Windows ver sion 24 (IBM Corp., Armonk, USA) and Microsoft Of fice 365 Excel Version 1911.
# Assigned Labels: ['Others']
#
# For Sentence: Results Comparison over two generations We specified the LMS models as 3/8/5 for girls and 3/6/ 4 for boys.
# Assigned Labels: []
#
# For Sentence: Sex-specific values of P10, P50 and P90 are presented in Fig.
# Assigned Labels: []
#
# For Sentence: On P10, girls today with Swiss parents still weigh the same as girls two generations ago.
# Assigned Labels: []
#
# For Sentence: On P50, girls are not heavier until puberty, and then are about 1 kg/m2 heav ier (equivalent to 2.8 kg at P50 height) by 17 years of age.
# Assigned Labels: []
#
# For Sentence: On P90, girls above age 4 and onwards are now heavier than two generations ago with the biggest differ ences occurring at the age of 7 with 1 kg/m2 (1.5 kg) and to 18 years (2 kg/m2, 5.5 kg).
# Assigned Labels: []
#
# For Sentence: 1 BMI-for-age percentiles of (a) girls and (b) boys with both parents of Swiss origin compared with the smoothed percentiles of Prader et al.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: For orientation, new BMI percentiles for Switzerland [3] were added Eiholzer et al.
# Assigned Labels: []
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 4 of 11 Overweighta Obese Overweighta Obese Table 1 Rates of overweight and obesity (in percent) according to parent origin Origin of both parents Switzerland Northern/Central Europe Italy, Spain, Portugal Balkan region Turkey One parent from Switzerland other parent: Northern/Central Europe other parent: Italy, Spain, Portugal other parent: Balkan region other parent: Turkey other parent: from other regions Not from the same region/from other regions Girls n 2816 1032 383 326 526 135 312 238 74 22 386 778 8.8 7.0 19.9 22.1 23.0 9.4 8.3 11.3 6.8 13.6 9.3 17.5 Boys n 2867 1084 387 435 758 144 348 223 89 22 402 872 9.6 5.4 20.5 28.3 25.0 9.0 7.5 9.0 11.2 18.2 9.5 16.5 1.6 0.8 6.1 6.5 5.2 1.6 0.6 2.5 0 0 2.3 3.0 1.2 1.0 5.7 9.5 6.3 1.6 1.7 0.9 4.5 4.5 1.0 3.6 5996 Total χ2testb χ2testc a Category including obese subjects defined by the International Obesity Task Force (IOTF) cut-offs [8] b χ2test for association between IOTF category (non-overweight, overweight, obese) and origin of both parents (all categories) c χ2test for association between IOTF category (non-overweight, overweight, obese) and origin of both parents (Switzerland versus Southern Europe) d One expected cell frequency was smaller than 5 (Northern/Central Europe) 12.0 2.5 χ2(12) = 169.96; p < 0.001d χ2(2) = 119.93; p < 0.001 13.4 2.9 χ2(12) = 313.53; p < 0.001d χ2(2) = 217.51; p < 0.001 6547 Fig.
# Assigned Labels: ['Data Analysis', 'Empirical Study']
#
# For Sentence: 2 Distributions of origin in the categories of overweight (including obesity) (n = 1599) and obesity (n = 339) according to the International Obesity Task Force (IOTF) cut-off criteria [8] and in the contemporary core sample (n = 12,543, age: 2–19 years) Eiholzer et al.
# Assigned Labels: []
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 5 of 11 Fig.
# Assigned Labels: []
#
# For Sentence: 3 Deviations from the empirical cumulative distribution function (EDF) of percentile ranks compare the sex-specific subgroups and the Prader sample [4] to the sample of Eiholzer et al.
# Assigned Labels: ['Empirical Study']
#
# For Sentence: Lines above and below the zero line indicate a higher proportion of thinner and overweight children and adolescents, respectively Fifteen and 6% of today’s proportion of girls lie above the Prader P90 and P97, respectively.
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: Similar trends on all percentiles were also observed for the boys with both parents of Swiss origin.
# Assigned Labels: ['Data Analysis', 'Decision Making', 'Social Analysis', 'Clinical Decision Support', 'Systematic Review']
#
# For Sentence: On P50, boys are heavier by 0.7 kg/m2 from 11 years (1.5 kg) onwards to 17 years (2.2 kg).
# Assigned Labels: []
#
# For Sentence: On P90, boys are significantly heav ier and the difference increases with age from about 1 kg/m2 at 7 years to 2 kg/m2 at 18 years (6.4 kg at P50 height).
# Assigned Labels: []
#
# For Sentence: Eighteen and 10% of today’s proportion of boys lie above the respective Prader P90 and P97.
# Assigned Labels: []
#
# For Sentence: Differentiation by parent origin Children of parents from Northern/Central Europe or Switzerland have lower rates of overweight and obesity than children whose parents originate from Southern Europe (Table 1).
# Assigned Labels: ['Data Analysis']
#
# For Sentence: From our data set, 18% of children have parents from Southern Europe, but these children account for 29% (girls) and 39% (boys) of all children in Switzerland who are overweight and even make up 41% (girls) and 57% (boys) of all obese children (Fig.
# Assigned Labels: []
#
# For Sentence: Comparison of BMI percentile distributions by origin and between two generations There was very little influence on the BMI percentile distribution when comparing children with both parents originating from Switzerland to children with only one parent originating from Switzerland (Fig.
# Assigned Labels: []
#
# For Sentence: Boys and girls with parents from Southern Europe are generally heavier based on the negative deviations over the whole range of percentile ranks.
# Assigned Labels: ['Discrimination', 'Data Analysis', 'Social Analysis', 'Regional Implementation']
#
# For Sentence: Compared to the entire sam ple, there are about 10% less children with Southern European origins below P50 and P75.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Conversely, there are about 10% more children from Northern/Central Europe below P50.
# Assigned Labels: ['Regional Implementation', 'Social Analysis', 'Data Analysis']
#
# For Sentence: Children and adolescents from the Prader sample with a BMI around P97 of our contemporary core sample were rare; BMI distribution deviations of the Prader sample show more children around P3 and none above P97.
# Assigned Labels: []
#
# For Sentence: The proportion of girls with either one or two parents of Swiss origin at P50 is identical with the Prader sample (Fig.
# Assigned Labels: []
#
# For Sentence: Boys, irrespective of their parents’ origin, are heavier than two generations ago.
# Assigned Labels: ['Empirical Study', 'Discrimination']
#
# For Sentence: At P50, the proportion of boys from the Prader sample is 10% higher than our contemporary core sample and 3% higher than boys with two parents of Swiss origin.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Comparison of origin-specific P50 with national BMI percentiles Italy, Spain, Portugal We specified the LMS models as 3/7/3 for girls and 3/7/ 4 for boys.
# Assigned Labels: []
#
# For Sentence: Up to 9 years, P50 of girls with both parents from Italy, Spain or Portugal resembles our contempor ary P50 of Switzerland (Fig.
# Assigned Labels: []
#
# For Sentence: From age 10 onwards, P50 for this subgroup rises more steeply and becomes 1.5 kg/m2 higher at the age of 14 (3.9 kg at P50 height) and corresponds closely to P50 of girls from Southern Italy.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: P50 of boys with both parents from Italy, Spain or Portugal are similar to the contemporary P50 of Switzerland until 6 years only.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: Thereafter, P50 steeply rises and is about 1 kg/m2 higher from 10 years on, with a less emphasized difference at 15 years (2 kg at age 10 and 3 kg at age 18).
# Assigned Labels: []
#
# For Sentence: P50 for this male subgroup is lower than P50 of Northern/Central and Southern Italy only until around the age of 17 years, where it then exceeds the published country-specific value.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 6 of 11 Fig.
# Assigned Labels: []
#
# For Sentence: 4 Raw subgroup data of children with parents from Italy/Spain/Portugal, Balkan region, Turkey, and Northern/Central Europe plotted against the new P10, P50 and P90 for Switzerland [3].
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: Group-specific P10, P50 and P90 are indicated as well as the established values for respective European countries/regions.
# Assigned Labels: []
#
# For Sentence: Data are given as the arithmetic mean for references marked with # Balkan region We specified the LMS models as 3/5/3 for girls and 3/7/ 3 for boys.
# Assigned Labels: ['Regional Implementation', 'Data Analysis']
#
# For Sentence: From the age of 4 years, P50 of girls with par ents from the Balkan region is higher than the contem porary P50 of Switzerland (Fig.
# Assigned Labels: []
#
# For Sentence: Between 6 and 12 years, their P50 is about 0.5 kg/m2 higher (1 kg at P50 height) and at 18 years, this value is 2 kg/m2 higher (5.5 kg).
# Assigned Labels: []
#
# For Sentence: P50 for this subgroup corresponds to P50 for both Albanian-born girls living in the Balkan region and Ma cedonian girls aged 6–7 years.
# Assigned Labels: ['Data Analysis', 'Regional Implementation', 'Social Analysis']
#
# For Sentence: For boys with parents from the Balkan region, their P50 corresponds up to 8 years with the contemporary P50 of Switzerland.
# Assigned Labels: ['Regional Implementation']
#
# For Sentence: At the age of 12 years, their P50 is 1 kg/m2 (2.3 kg) higher and at the age of 18 years, it is 2.2 kg/m2 (7 kg) higher.
# Assigned Labels: []
#
# For Sentence: Their P50 is lower than P50 of Macedonian 6–7year-old boys.
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: From the age of 12, their P50 continually exceeds that of Albanian-born boys living in the Balkan region.
# Assigned Labels: ['Decision Making', 'Social Analysis', 'Data Analysis', 'Empirical Study']
#
# For Sentence: For both girls and boys, there were more children above the country-specific P97 than the 3% expected.
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: Turkey We specified the LMS models as 3/5/3 for both girls and boys.
# Assigned Labels: []
#
# For Sentence: From our contemporary core sample, P50 of girls with parents from Turkey is higher than the contempor ary P50 of Switzerland from 4 years of age; the max imum difference is 1.6 kg/m2 at 14 years (Fig.
# Assigned Labels: []
#
# For Sentence: P50 of Turkish girls in the Netherlands is similar to children of Turkish origin in Switzerland, but P50 for girls with Turkish origin in Germany is higher.
# Assigned Labels: ['Regional Implementation', 'Social Analysis', 'Data Analysis']
#
# For Sentence: P50 of boys with Turkish parents is slightly higher than the contemporary P50 of Switzerland during childhood.
# Assigned Labels: ['Social Analysis', 'Data Analysis']
#
# For Sentence: From 11 years onwards, the difference exceeds 1 kg/m2 with a maximum of 1.8 kg/m2 at the age of 16 (5.5 kg at P50 height) and is similar to P50 of boys in Western Turkey.
# Assigned Labels: []
#
# For Sentence: P50 of Turkish boys in Switzerland is similar to Turkish children in the Netherlands until the age of 12, and then Turkish boys in Switzerland are heavier.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: P50 of and boys with Turkish origin in both Germany Eiholzer et al.
# Assigned Labels: ['Evidence From Patients']
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 7 of 11 Table 2 Logistic regression model coefficients for predicting overweight or obesity from origina and SSEPb Model 95% CI for regression coefficients β 95%CI for odds ratio Predictor Overweight, girls origin Overweight, boys origin Obesity, girls Obesity, boys Lower −1.38 −0.03 −0.83 −1.35 − 0.03 −0.41 −1.52 −0.08 −1.12 −2.52 −0.05 −2.18 SSEP constant SSEP constant origin SSEP constant origin SSEP constant β − 1.13 − 0.02 0.06 −1.15 −0.02 0.32 −1.02 −0.06 0.63 −2.04 −0.02 −0.74 Upper −0.87 0.00 0.96 −0.94 − 0.01 1.06 −0.52 − 0.03 2.38 −1.55 0.00 0.71 Lower Upper Odds eβ 0.32 p value Model fit 0.25 0.97 0.44 0.26 0.97 0.66 0.22 0.92 0.33 0.08 0.95 0.11 0.98 1.06 0.32 0.98 1.38 0.36 0.95 1.88 0.13 0.98 0.48 0.42 1.00 2.60 0.39 0.99 2.88 0.60 0.97 10.81 0.21 1.00 2.02 0.000 0.010 0.892 0.000 0.003 0.387 0.000 0.000 0.479 0.000 0.043 0.317 McFadden’s R2 = 0.05, LR X2(2) = 90.30, p = 0.000 McFadden’s R2 = 0.06, LR X2(2) = 144.04, p = 0.000 McFadden’s R2 = 0.06, LR X2(2) = 36.10, p = 0.000 McFadden’s R2 = 0.12, LR X2(2) = 101.76, p = 0.000 a Dichotomized into 1 = ‘both parents from Switzerland’ versus 0 = ‘both parents from Southern Europe’ b Swiss socioeconomic position index, interval scale, median, 65.2 (interquartile range, 58.7–72.0) CI confidence interval, LR X2 likelihood ratio chi-square Switzerland at the age of 16 is similar, but younger boys in Germany are heavier.
# Assigned Labels: ['Public Health Law', 'Data Analysis', 'Medical Report', 'Community Outreach']
#
# For Sentence: Northern/Central Europe We specified the LMS models as 3/5/3 for both girls and boys.
# Assigned Labels: ['Regional Implementation']
#
# For Sentence: P50 of girls with parents from Northern/Central Europe corresponds up to the age of 5 with the contem porary P50 of Switzerland.
# Assigned Labels: ['Regional Implementation']
#
# For Sentence: Thereafter, their P50 is lower and the greatest difference of 1 kg/m2 (2.5 kg at P50 height) occurs at 10 to 15 years (Fig.
# Assigned Labels: []
#
# For Sentence: They are also less heavy compared to P50 of German girls with a max imum difference of 2 kg/m2 at the age of 13 years (5 kg) and to P50 of Austrian girls with a maximum difference of 1.8 kg/m2 at the age of 10 years (3.6 kg).
# Assigned Labels: []
#
# For Sentence: The results for boys with both parents from Northern/Central Eur ope are similar.
# Assigned Labels: ['Data Analysis', 'Empirical Study', 'Social Analysis', 'Regional Implementation', 'Clinical Decision Support']
#
# For Sentence: The greatest difference to the contem porary P50 of Switzerland is between 12 to 15 years with about 1 kg/m2 (2.3 to 3 kg).
# Assigned Labels: []
#
# For Sentence: 5 The relation between the Swiss neighbourhood index of Socioeconomic position (SSEP) and the chance of being overweight or obese for a. girls and b. boys with parental origin from Switzerland and from Southern Europe.
# Assigned Labels: []
#
# For Sentence: The black triangles depict the 25th, 50th and 75th centiles of the observed SSEP Eiholzer et al.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 8 of 11 compared to P50 of both German and Austrian boys, where the difference is approximately 1.8 kg/m2 at the age of 11 to 13 years (3.9 to 4.5 kg).
# Assigned Labels: []
#
# For Sentence: Differentiation by socioeconomic position index The SSEP index has little association with the probabil ities of being overweight or obese (Table 2).
# Assigned Labels: []
#
# For Sentence: The prob ability of being overweight is about 2.5 times higher for children whose parents both come from Southern Eur ope than for children with both parents coming from Switzerland (Fig.
# Assigned Labels: []
#
# For Sentence: The probability of being obese is 7 fold higher for boys and 2.7fold higher for girls with parents from Southern Europe than for children with both parents coming from Switzerland.
# Assigned Labels: ['Regional Implementation', 'Data Analysis', 'Social Analysis']
#
# For Sentence: [4] were recently compared with contemporary BMI references [3].
# Assigned Labels: ['Empirical Study', 'Data Analysis']
#
# For Sentence: Two generations lie between these two data sets and the current BMI percentile curves, including all children of Switzerland, are higher, which signifies heavier children in present-day Switzerland.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: In Switzerland, we are in the privileged situation of having a compulsory population register, a statistical evaluation of immigrants and emi grants, and an area-based measurement of SSEP.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: This enables us to investigate the association of generational, migration-related and socioeconomic factors with the observed BMI.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: To investigate differences in BMI between the two generations independent of migratory factors, we ex cluded children with parents of non-Swiss origin from the contemporary core sample and compared only the BMI percentiles of children with two parents of Swiss origin and the Prader BMI percentiles, which included only Swiss children.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: P10 and P50 for girls were practic ally the same between the two generations, while P90 in creased.
# Assigned Labels: []
#
# For Sentence: For boys, the whole distribution shifted in a skewed fashion.
# Assigned Labels: ['Social Analysis', 'Data Analysis']
#
# For Sentence: From 4 years of age, the heaviest 10% of children and adolescents are considerably heavier today compared to children two generations ago.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: This phenomenon of increasing skewness in the BMI distri bution has already been described and is attributed to a distinct subgroup that is genetically susceptible to obes ity [22].
# Assigned Labels: []
#
# For Sentence: The IOTF cut-off for obesity throughout child hood and adolescence lies close to P100 of the Prader sample.
# Assigned Labels: []
#
# For Sentence: This implicates that there were very few obese children in the Swiss city of Zurich two generations ago, although one should keep in mind the uncertainty of P100 due to the small case numbers included in the Pra der longitudinal study.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Of today’s children with parents originating from Switzerland, 1.2 and 1.6% of girls and boys respectively, are obese according to the IOTF definition.
# Assigned Labels: []
#
# For Sentence: Boys and girls with parents originating from countries of Southern Europe have a 2.5fold higher risk of being overweight.
# Assigned Labels: ['Risk Management', 'Social Analysis', 'Data Analysis']
#
# For Sentence: While we found the same ratio for obese girls, this risk was 7fold elevated for boys with parents from Southern Europe.
# Assigned Labels: ['Data Analysis', 'Risk Management', 'Social Analysis']
#
# For Sentence: Of all obese children in Switzerland, 57% of boys and 41% of girls have parents from Southern Europe, although the part of this immi grant group in Switzerland is only 13%.
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: This shows that the increase in BMI of children in Switzerland is mainly due to the immigration of persons from Southern Eur ope into Switzerland, and not from an increase in weight of the local population.
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: If immigrants would not have been included in the recent calculations of BMI percen tiles [3], the increase of P90 would be less than half compared to the Prader study.
# Assigned Labels: []
#
# For Sentence: Marked variations in overweight and obesity preva lence between children from Northern and Central Europe versus Southern European origins is in line with recent findings [1, 23, 24].
# Assigned Labels: ['Data Analysis', 'Regional Implementation']
#
# For Sentence: This is also consistent with findings in the adult population of Switzerland, where adults from Northern Europe had the lowest prevalence of overweight and obesity while people from Southern Europe showed the highest [25].
# Assigned Labels: ['Data Analysis', 'Regional Implementation']
#
# For Sentence: The origin of parents has been highlighted for its import ant role in the prevalence of overweight and obesity [2, 26], however these studies insufficiently classified their study populations into only Swiss and non-Swiss groups.
# Assigned Labels: []
#
# For Sentence: Only one study, limited to school children liv ing in the city of Geneva, examined the influence of individual national migrant groups and could high light the strong influence of nationality on the preva lence of overweight and obesity [27].
# Assigned Labels: []
#
# For Sentence: Based on the fact that Europeans from both southern and northern regions are among the largest groups of Swiss immi grants, it is very important to acknowledge their pro portions in study samples, especially when comparing the prevalence of overweight and obesity over a cer tain period of time.
# Assigned Labels: []
#
# For Sentence: The Swiss BMI Monitoring work ing group, responsible for all epidemiological research on childhood BMI under governmental mandate, has yet to consider this fact.
# Assigned Labels: []
#
# For Sentence: The group found a 4% de crease in the prevalence of overweight in children of non-Swiss origin (living in Zurich, Berne and Basel) between 2005 and 2017, and interpreted this trend as a positive development in prevention [26].
# Assigned Labels: ['Data Analysis', 'Social Analysis', 'Regional Implementation']
#
# For Sentence: Neverthe this change is due less, solely to changes in migration.
# Assigned Labels: []
#
# For Sentence: For example, the per centages of children in the city of Zurich changed be tween 2005 and 2017 as follows: Switzerland + 13%, Northern/Central Europe + 4%, Balkan region − 11%, Italy/Spain/Portugal − 4%, and Turkey − 2% [28].
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: On the basis of the overweight rates per region of origin and the changing proportions of children per group of origin, we can calculate a decline in the overall is highly probable that it Eiholzer et al.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 9 of 11 overweight rate of 2.5% for all children or 3.5% for children of non-Swiss origin during this time period, which is exclusively due to the altered migration.
# Assigned Labels: []
#
# For Sentence: The exclusion of changes in national proportions of the different migrant groups leads to further incorrect weighting.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Northern and Southern European immigrants belong to different social groups that have different functions within the Swiss economic system; the differ ences in levels of income and education between the two groups are substantial [29].
# Assigned Labels: []
#
# For Sentence: The immigrant population of Southern European people are mainly less qualified workers, while immigrants from northern countries are advantaged both in terms of an above-average propor tion with a tertiary education and the countries’ socio economic situation.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: Due to this heterogeneity of the non-Swiss group, the simple differentiation between Swiss and non-Swiss children is inappropriate for further analysis of the impact of income and education on BMI.
# Assigned Labels: []
#
# For Sentence: From the logistic regression analysis in this study, so cioeconomic differences practically vanish behind the re gion of parental origin.
# Assigned Labels: []
#
# For Sentence: We think that people from the same region, who leave their country during a similar time period and probably for similar reasons, share many characteristics such as genetic traits, cultural habits, eating habits, level of education as well as values and attitudes.
# Assigned Labels: ['Lifestyle Factors']
#
# For Sentence: It is therefore plausible that the area of origin is more predictive of the risk of overweight or obesity than socioeconomic parameters alone.
# Assigned Labels: []
#
# For Sentence: How well do the new Swiss BMI curves fit children of immigrants from the various European regions?
# Assigned Labels: ['Data Analysis', 'Global Health']
#
# For Sentence: To help pediatricians interpreting the BMI of children with par ents of non-Swiss origin, we provide graphs showing the BMI values of all respective children presented as data points in conjunction with the new Swiss percentiles [3] and those of the countries of parent origin.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: From the age of 6, the BMI P50 of children from Southern Europe lies above P50 of the new Swiss curves, yet largely corre sponds to the P50 of their countries of origin, except for Turkey where large regional BMI differences exist.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: P50 of the Northern European countries lies below the P50 of the new Swiss curves as well as below the P50 of the countries of origin.
# Assigned Labels: []
#
# For Sentence: This is probably due to the fact that this particular subgroup is advantaged both in terms of an above-average proportion with a tertiary education and the countries’ socioeconomic status.
# Assigned Labels: []
#
# For Sentence: The majority of our study participants live in the can ton of Zurich.
# Assigned Labels: ['Regional Implementation']
#
# For Sentence: One could therefore assume that our BMI study is not representative of Switzerland as a whole.
# Assigned Labels: []
#
# For Sentence: However, the main variable for BMI is the varying pro portions of foreigner groups.
# Assigned Labels: []
#
# For Sentence: In terms of the proportion of foreigners, the canton of Zurich, in fact, provides an optimal representation of the entire country because the proportions of multicultural diversity closely match the overall proportions distributed across all 26 cantons of Switzerland [30].
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: A number of cantons, particularly in the French speaking parts of Vaud and Fribourg, were difficult to study as they did not wish to participate in a national evaluation of anthropometric parameters in school children [2].
# Assigned Labels: []
#
# For Sentence: In the official Swiss statistics on population, 13% of children and adolescents aged 0 to 19 years come from Southern Europe [30].
# Assigned Labels: []
#
# For Sentence: The respect ive percentage from our contemporary core sample is 18%.
# Assigned Labels: ['Empirical Study']
#
# For Sentence: The official Swiss statistic is based on nationality, whereas this study targeted the origin of the parents.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: The difference in percentages is based on the acquisition in the canton of of Swiss citizenship.
# Assigned Labels: []
#
# For Sentence: For example, Zurich, 37% of Swiss citizenship was obtained by people originating from Serbia (including Montenegro and Kosovo), Macedonia, Croatia and Bosnia-Herzegovina between 1994 and 2009 [31].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Limitations Our study is restricted by the lack of information regard ing the percentage of the Swiss group comprising second or higher generation immigrants.
# Assigned Labels: []
#
# For Sentence: To date, there is an es timated 7.2% of second-generation immigrants and 0.3% of third-generation or higher immigrants from the Swiss population who are aged 15 years and older [32].
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: We as sume that a proportion of our sample of children with both parents of Swiss origin are, in fact, children of second-generation immigrants who certainly have higher cultural and genetic diversity compared to the Prader sample.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Furthermore, we do not have data on the length of residence of immigrant children and parents since ar riving in Switzerland.
# Assigned Labels: []
#
# For Sentence: Within the last 8 years, 70% of children of foreign nationalities living in Switzerland were born in Switzerland [33].
# Assigned Labels: ['Data Analysis', 'Social Analysis']
#
# For Sentence: This suggests that the majority of the children in our sample have spent most of their childhood in Switzerland.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: This value is even higher (90 to 96%) for children with parents from the Balkan region (Kosovo, Serbia, Northern Macedonia) or Turkey.
# Assigned Labels: ['Regional Implementation', 'Social Analysis']
#
# For Sentence: Conclusion Immigration from South European countries accounts for the main part of the increase in BMI and the preva lence of overweight and obesity in Switzerland.
# Assigned Labels: ['Global Health', 'Social Analysis']
#
# For Sentence: Many European studies only distinguish between na tives and immigrants [2, 24, 26], but not all immigrants are alike.
# Assigned Labels: []
#
# For Sentence: Immigrants from Southern Europe are mainly less qualified workers with a low educational status and there is already a higher BMI and an increased preva lence of overweight and obesity in their country of ori gin.
# Assigned Labels: ['Lifestyle Factors', 'Social Analysis']
#
# For Sentence: Immigrants from Northern and Central Europe, on the other hand, are in higher economic positions and their BMI is comparable to Switzerland.
# Assigned Labels: ['Lifestyle Factors', 'Social Analysis', 'Regional Implementation']
#
# For Sentence: Hence, a de creased percentage of the prevalence of obesity can also Eiholzer et al.
# Assigned Labels: ['Empirical Study']
#
# For Sentence: BMC Public Health          (2021) 21:243  Page 10 of 11 be caused by higher immigration from northern Euro pean countries.
# Assigned Labels: []
#
# For Sentence: Children with parents of Swiss origin serve as an adequate comparison group to the sample of Prader and colleagues.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Among the Swiss, only the heaviest children (P90) have become heavier, otherwise the difference among the two generations is rather mar ginal.
# Assigned Labels: ['Social Analysis']
#
# For Sentence: We could also show that socioeconomic differ ences in Switzerland are less important than national origin with regard to the risk of overweight and obes ity.
# Assigned Labels: ['Data Analysis', 'Risk Management', 'Social Analysis', 'Empirical Study']
#
# For Sentence: A differentiated view regarding origin is essential for countries with large migrant populations in order to better understand the mechanisms of the preva lence of overweight and obesity.
# Assigned Labels: []
#
# For Sentence: Abbreviations BMI: Body mass index; EDF: Empirical cumulative distibution function; IOTF: International Obesity Task Force; Pn: nth percentile (e.g.
# Assigned Labels: ['Empirical Study']
#
# For Sentence: P50 = 50th percentile); SSEP: Swiss neighborhood index of socioeconomic position Acknowledgements We would like to thank the 64 pediatricians and 21 schools that participated in the data collection.
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Special thanks to Melissa Wilhelmi for proofreading our manuscript.
# Assigned Labels: []
#
# For Sentence: Competing interests The authors declare that they have no competing interests.
# Assigned Labels: []
#
# For Sentence: Funding Support for this research was provided by the Foundation Growth Puberty Adolescence.
# Assigned Labels: ['Publicly Funded Science']
#
# For Sentence: The funding body had no influence on study design, data collection, analysis and interpretation of data, writing of the manuscript and in the decision to submit the manuscript for publication.
# Assigned Labels: ['Decision Making', 'Data Analysis', 'Empirical Study']
#
# For Sentence: Availability of data and materials Permission for the data sets used and/or analysed during the current study was granted by the corresponding author of reference [3].
# Assigned Labels: ['Data Analysis']
#
# For Sentence: Authors’ contributions UE formulated the research idea, contributed to the overall design and interpretation of the data and prepared the original draft.
# Assigned Labels: ['Data Analysis', 'Empirical Study']
#
# For Sentence: AS developed the methodology, carried out the statistical analysis and drafted the methods and results sections of the manuscript.
# Assigned Labels: ['Data Analysis', 'Empirical Study']
#
# For Sentence: CF was a major contributor in writing the manuscript.
# Assigned Labels: ['Empirical Study', 'Community Outreach', 'Clinical Decision Support']
#
# For Sentence: All authors read and approved the final version of the manuscript.
# Assigned Labels: ['Clinical Decision Support']
#
# For Sentence: Ethics approval and consent to participate Not applicable.
# Assigned Labels: []
#
# For Sentence: Our research project included data regarded as “anonymously collected health-related data”, which does not fall under the Human Research Act according to Swiss law (Human Research Act, 2014, Art icle 2).
# Assigned Labels: []
#
# For Sentence: Therefore, the local Ethics Committee of the Canton of Zurich formally waived the need for ethics approval and stated that the study is ethically harmless (Req2017440).
# Assigned Labels: ['Regional Implementation']
#
# Final Count: [('Data Analysis', 82), ('Social Analysis', 41), ('Regional Implementation', 22), ('Empirical Study', 17), ('Clinical Decision Support', 6), ('Global Health', 6), ('Risk Management', 5), ('Decision Making', 4), ('Lifestyle Factors', 4), ('Others', 4), ('Community Outreach', 3), ('Discrimination', 2), ('Publicly Funded Science', 2), ('Evidence From Patients', 1), ('Global Threats', 1), ('Medical Report', 1), ('Propositions and Guidelines', 1), ('Public Health Law', 1), ('Systematic Review', 1), ('Artificial Intelligence', 0), ('Biomedical Engineering', 0), ('Computer Vision', 0), ('Diagnostic Assessments', 0), ('Digital Accelerators', 0), ('Digital Health', 0), ('eHealth', 0), ('Electronic Health Records', 0), ('Environmental Conservation', 0), ('Healthcare Financing', 0), ('Human Rights', 0), ('Humanitarian Response', 0), ('Knowledge Management', 0), ('Literature Review', 0), ('Logistics and Supply Chain', 0), ('Medical Imaging', 0), ('Natural Language Processing', 0), ('Substance Abuse', 0), ('Surgery', 0), ('Sustainable Development Goals', 0), ('Telemedicine', 0), ('Violence', 0)]
